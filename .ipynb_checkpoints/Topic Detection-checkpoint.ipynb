# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
import json
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import time
import pickle
import collections
import os
import re

# %%
with open("data/twitter-swisscom/twitter/df1_reduced.pickle", "rb") as f:
    df1 = pickle.load(f)

# %%
with open("data/twitter-swisscom/twitter/df2_reduced.pickle", "rb") as f:
    df2 = pickle.load(f)

# %%
with open("data/twitter-swisscom/twitter/df3_reduced.pickle", "rb") as f:
    df3 = pickle.load(f)

# %%
with open("data/twitter-swisscom/twitter/df4_reduced.pickle", "rb") as f:
    df4 = pickle.load(f)

# %%
with open("data/twitter-swisscom/user/user_total.pickle", "rb") as f:
    user = pickle.load(f)

# %%
df4['day'] = df4['createdAt'].apply(lambda x: x[:10])

# %% [markdown]
# ## Base and Tags
#
# Use df1, df2, df3 (date before 2015) as base, the df4 is investigate to detect changes.

# %%
def count_hash_tags(series):
    d = collections.defaultdict(int)
    
    def count_a_list(l):
        for i in l:
            d[i.lower()] += 1
            
    series.apply(count_a_list)
    return d

# %%
d1 = count_hash_tags(df1['hashtags'])
d2 = count_hash_tags(df2['hashtags'])
d3 = count_hash_tags(df3['hashtags'])
d4 = count_hash_tags(df4['hashtags'])

# %% [markdown]
# Merge dictionaries

# %%
num_base_twitters = df1.shape[0] + df2.shape[0] + df3.shape[0]

# %%
base_dict = collections.defaultdict(int, {k: d1[k] + d2[k] + d3[k] for k in set(d1) | set(d2)| set(d3)})

# %%
def sort_dict_values(d, reverse=False):
    return sorted(d.items(), key=lambda x: x[1], reverse=reverse)

# %% [markdown]
# # Detect Topic in Dict

# %%
from scipy.stats import chisquare

# %%
def topic_detection_by_chi_square(past, future, N, future_length, n=20):
    all_keys = set(future.keys()) | set(past.keys())
    chi_squared_score = collections.defaultdict(float)

    for k,v in future.items():
        if N == 0:
            expected = past[k] * future_length or 1
        else:        
            expected = past[k] / N * future_length or 1
            
#         print(expected, v, past[k], N, future_length)
#         print(v)
        if v > expected and v > n:
            chi_squared_score[k] = (np.abs(expected - v)-0.5) ** 2 / expected
        
    return sort_dict_values(chi_squared_score, True)

# %% [markdown]
# # Overal Topic Trend

# %%
total_N = num_base_twitters

# %%
total_base_dict = base_dict.copy()

# %%
def overal_topic(date_df, total_base_dict, total_N, n=20):
    num_twitters_in_a_day = date_df.shape[0]
    future = count_hash_tags(date_df.hashtags)
    
    chi_squared_dict = topic_detection_by_chi_square(total_base_dict, future, total_N, num_twitters_in_a_day, n)
    
    for k,v in future.items():
        total_base_dict[k] += v

    return chi_squared_dict[:5], total_N + num_twitters_in_a_day

# %%
days = df4.day.unique()

# %%
v = []
for i, day in zip(range(10000), days):
    df = df4[df4.day == day]
    a = [day]
    result, total_N = overal_topic(df, total_base_dict, total_N)
    a.extend(result)
    v.append(a)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-bd7e0557d3ec> in <module>()
#       1 v = []
#       2 for i, day in zip(range(10000), days):
# ----> 3     df = df4[df4.day == day]
#       4     a = [day]
#       5     result, total_N = overal_topic(df, total_base_dict, total_N)
#
# /home/lie/.local/lib/python3.5/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# /home/lie/.local/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# /home/lie/.local/lib/python3.5/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#     737         result = lib.vec_compare(x, y, op)
#     738     else:
# --> 739         result = lib.scalar_compare(x, y, op)
#     740     return result
#     741
#
# KeyboardInterrupt:

# %%
overall_topics = pd.DataFrame(v)

# %%
overall_topics.head()
# Out:
#          date                                         1  \
# 0  2014-12-28       (davidebraccialetti, 123261065.614)
# 1  2014-12-29  (switzerlandneedsotratour, 33731885.168)
# 2  2014-12-30  (switzerlandneeds1dotrat, 4787810.32671)
# 3  2014-12-31        (weneedotrainitaly2015, 825372.25)
# 4  2015-01-01             (ilovesuperjunior, 924482.25)
#
#                                         2  \
# 0      (braccialettirossi, 1090408.47591)
# 1  (wewantotrainitaly2015, 59691.9480146)
# 2   (20thingsiwantfor2015, 1301800.37258)
# 3        (openrafahborder, 805625.184103)
# 4               (ilovebts, 170625.650474)
#
#                                            3  \
# 0     (switzerlandneedsotrat, 3840.32787285)
# 1    (yeniturkiyei̇nsasindafelsefe, 5852.25)
# 2  (switzerlandneedsotratour, 469414.364522)
# 3                      (2015, 103923.947519)
# 4                  (dmmedagi, 117581.106526)
#
#                                         4  \
# 0       (atamadafelsefeyiunutma, 1332.25)
# 1  (switzerlandneedsotrat, 1447.49075187)
# 2          (neolieberswag, 17131.6748847)
# 3           (happynewyear, 35881.7318057)
# 4                   (2015, 77109.7463785)
#
#                                        5
# 0           (switzerland, 14.3109812746)
# 1    (nashschristmasskit, 1447.30046921)
# 2  (hollywoodmusicawards, 12773.2957978)
# 3  (20thingsiwantfor2015, 29640.7442074)
# 4          (happynewyear, 14038.5748095)

# %%
overall_topics.to_csv("web/Analysis/overall_topics.csv", index=False)

# %%
l = []
for day in days:
    sub_df = df4[df4.day == day]
    candidate = df.loc[day][1]
    print(day)
    if not isinstance(candidate, str):
        l.append([day, None, None])
        continue

    pair = eval(df.loc[day][1])
    hashtag_name = pair[0]
    sub_df1 = sub_df['hashtags'].apply(lambda x: hashtag_name in x)
    a = sub_df[sub_df1]['placeId'].value_counts()
    
    l.append([day, a.index[0], a[0]])
# Out:
# 2014-12-28
# 2014-12-29
# 2014-12-30
# 2014-12-31
# 2015-01-01
# 2015-01-02
# 2015-01-03
# 2015-01-04
# 2015-01-05
# 2015-01-06
# 2015-01-07
# 2015-01-08
# 2015-01-09
# 2015-01-10
# 2015-01-11
# 2015-01-12
# 2015-01-13
# 2015-01-14
# 2015-01-15
# 2015-01-16
# 2015-01-17
# 2015-01-18
# 2015-01-19
# 2015-01-20
# 2015-01-21
# 2015-01-22
# 2015-01-23
# 2015-01-24
# 2015-01-25
# 2015-01-26
# 2015-01-27
# 2015-01-28
# 2015-01-29
# 2015-01-30
# 2015-02-08
# 2015-02-09
# 2015-02-10
# 2015-02-11
# 2015-02-12
# 2015-02-13
# 2015-02-14
# 2015-02-15
# 2015-02-16
# 2015-02-17
# 2015-02-18
# 2015-02-19
# 2015-02-20
# 2015-02-21
# 2015-02-22
# 2015-02-23
# 2015-02-24
# 2015-02-25
# 2015-02-26
# 2015-02-27
# 2015-02-28
# 2015-03-01
# 2015-03-02
# 2015-03-03
# 2015-03-04
# 2015-03-05
# 2015-03-06
# 2015-03-07
# 2015-03-08
# 2015-03-09
# 2015-04-22
# 2015-04-23
# 2015-04-24
# 2015-04-25
# 2015-04-26
# 2015-04-27
# 2015-04-28
# 2015-04-29
# 2015-04-30
# 2015-05-01
# 2015-05-02
# 2015-05-03
# 2015-05-04
# 2015-05-05
# 2015-05-06
# 2015-05-07
# 2015-05-08
# 2015-05-09
# 2015-05-10
# 2015-05-11
# 2015-05-12
# 2015-05-13
# 2015-05-14
# 2015-05-15
# 2015-05-16
# 2015-05-17
# 2015-05-18
# 2015-05-19
# 2015-05-20
# 2015-05-21
# 2015-05-22
# 2015-05-23
# 2015-05-24
# 2015-05-25
# 2015-05-26
# 2015-05-27
# 2015-05-28
# 2015-05-29
# 2015-05-30
# 2015-05-31
# 2015-06-01
# 2015-06-02
# 2015-06-03
# 2015-06-04
# 2015-06-05
# 2016-06-10
# 2016-06-11
# 2016-06-12
# 2016-06-13
# 2016-06-14
# 2016-06-15
# 2016-06-16
# 2016-06-17
# 2016-06-18
# 2016-06-19
# 2016-06-20
# 2016-06-21
# 2016-06-22
# 2016-06-23
# 2016-06-24
# 2016-06-25
# 2016-06-26
# 2016-06-27
# 2016-06-28
# 2016-06-29
# 2016-06-30
# 2016-07-01
# 2016-07-02
# 2016-07-03
# 2016-07-04
# 2016-07-05
# 2016-07-06
# 2016-07-07
# 2016-07-08
# 2016-07-09
# 2016-07-10
# 2016-07-11
# 2016-07-12
# 2016-07-13
# 2016-07-14
# 2016-07-15
# 2016-07-16
# 2016-07-17
# 2016-07-18
# 2016-07-19
# 2016-07-20
# 2016-07-21
# 2016-07-22
# 2016-07-23
# 2016-07-24
# 2016-07-25
# 2016-07-26
# 2016-07-27
# 2016-07-28
# 2016-07-29
# 2016-07-30
# 2016-07-31
# 2016-08-01
# 2016-08-02
# 2016-08-03
# 2016-08-04
# 2016-08-05
# 2016-08-06
# 2016-08-07
# 2016-08-08
# 2016-08-09
# 2016-08-10
# 2016-08-11
# 2016-08-12
# 2016-08-13
# 2016-08-14
# 2016-08-15
# 2016-08-16
# 2016-09-06
# 2016-09-07
# 2016-09-08
# 2016-09-09
# 2016-09-10
# 2016-09-11
# 2016-09-12
# 2016-09-13
# 2016-09-14
# 2016-09-15
# 2016-09-16
# 2016-08-17

# %%
df = pd.read_csv("web/Analysis/overall_topics.csv")

# %%
df.set_index('date', inplace=True)

# %%
df['place'] = df['1'].apply(lambda x: '')

# %%
df['has_event'] = df['1'].apply(lambda x: True)

# %%
df4['hashtags'] = df4['hashtags'].apply(lambda x: [i.lower() for i in x])

# %%
df.head()
# Out:
#                                                            1  \
# date
# 2014-12-28        ('davidebraccialetti', 123261065.61367945)
# 2014-12-29  ('switzerlandneedsotratour', 33731885.168040439)
# 2014-12-30   ('switzerlandneeds1dotrat', 4787810.3267061366)
# 2014-12-31              ('weneedotrainitaly2015', 825372.25)
# 2015-01-01                   ('ilovesuperjunior', 924482.25)
#
#                                                         2  \
# date
# 2014-12-28      ('braccialettirossi', 1090408.4759098201)
# 2014-12-29  ('wewantotrainitaly2015', 59691.948014615453)
# 2014-12-30   ('20thingsiwantfor2015', 1301800.3725766602)
# 2014-12-31        ('openrafahborder', 805625.18410325912)
# 2015-01-01                ('ilovebts', 170625.6504743275)
#
#                                                            3  \
# date
# 2014-12-28     ('switzerlandneedsotrat', 3840.3278728453806)
# 2014-12-29         ('yeniturkiyei̇nsasindafelsefe', 5852.25)
# 2014-12-30  ('switzerlandneedsotratour', 469414.36452214647)
# 2014-12-31                      ('2015', 103923.94751935355)
# 2015-01-01                  ('dmmedagi', 117581.10652550224)
#
#                                                         4  \
# date
# 2014-12-28            ('atamadafelsefeyiunutma', 1332.25)
# 2014-12-29  ('switzerlandneedsotrat', 1447.4907518659709)
# 2014-12-30           ('neolieberswag', 17131.67488468088)
# 2014-12-31           ('happynewyear', 35881.731805671974)
# 2015-01-01                   ('2015', 77109.746378452517)
#
#                                                        5 place has_event
# date
# 2014-12-28           ('switzerland', 14.310981274630031)            True
# 2014-12-29     ('nashschristmasskit', 1447.300469211865)            True
# 2014-12-30  ('hollywoodmusicawards', 12773.295797828736)            True
# 2014-12-31  ('20thingsiwantfor2015', 29640.744207429976)            True
# 2015-01-01          ('happynewyear', 14038.574809500005)            True

# %%
a = pd.DataFrame(l, columns=['date', 'placeId', 'place_value'])

# %%
with open("data/twitter-swisscom/geo/geo_info_total.pickle", "rb") as h:
    geo = pickle.load(h)

# %%
geo.head()
# Out:
# 1           placeId placeLatitude placeLongitude
# 0  000831c517105356       16.9866         103.94
# 1  000a93ad12003aaa       46.8911        7.51217
# 2  000b5d1aada9dcaa       46.9525         7.4459
# 3  0010c7694b04e371       47.4261        8.50569
# 4  0013241b7342de79       47.0462        8.30735

# %%
trend = pd.merge(df.reset_index(), a, on='date')

# %%
d = pd.merge(trend, geo, on='placeId', how='left').set_index('date')
d['has_event'] = d['1'].apply(lambda x: type(x) == str)

# %%
export = d[['1', 'has_event', 'place_value', 'placeLatitude', 'placeLongitude']]

# %%
export1 = export[export.has_event].copy()

# %%
export1.head()
# Out:
#                                                            1 has_event  \
# date
# 2014-12-28        ('davidebraccialetti', 123261065.61367945)      True
# 2014-12-29  ('switzerlandneedsotratour', 33731885.168040439)      True
# 2014-12-30   ('switzerlandneeds1dotrat', 4787810.3267061366)      True
# 2014-12-31              ('weneedotrainitaly2015', 825372.25)      True
# 2015-01-01                   ('ilovesuperjunior', 924482.25)      True
#
#             place_value placeLatitude placeLongitude
# date
# 2014-12-28        192.0       46.3293         9.4055
# 2014-12-29         22.0       46.2504        8.27646
# 2014-12-30         10.0       46.2219        6.18194
# 2014-12-31         34.0       47.3774        8.53676
# 2015-01-01         70.0       47.7218        7.28274

# %%
export1['topic'] = export1['1'].apply(lambda x: eval(x)[0])

# %%
export1['chi_squared'] = export1['1'].apply(lambda x: eval(x)[1])

# %%
export1[['place_value', 'placeLatitude', 'placeLongitude', 'topic', 'chi']]
# Out:
#                                                            1 has_event  \
# date
# 2014-12-28        ('davidebraccialetti', 123261065.61367945)      True
# 2014-12-29  ('switzerlandneedsotratour', 33731885.168040439)      True
# 2014-12-30   ('switzerlandneeds1dotrat', 4787810.3267061366)      True
# 2014-12-31              ('weneedotrainitaly2015', 825372.25)      True
# 2015-01-01                   ('ilovesuperjunior', 924482.25)      True
# 2015-01-02   ('barısatayyalnızdeğildir', 946800.60403752676)      True
# 2015-01-03                       ('울면안돼', 195384.7610251313)      True
# 2015-01-04                  ('camilahammersledge', 15252.25)      True
# 2015-01-05             ('desafiofinal3', 105373.70148716206)      True
# 2015-01-06                ('udineseroma', 532207.1210544887)      True
# 2015-01-07               ('charliehebdo', 27768920.20991635)      True
# 2015-01-08             ('jesuischarlie', 308963.26914058556)      True
# 2015-01-09                ('prisedotage', 2198994.047875958)      True
# 2015-01-10                   ('fcmfcsm', 799269.11849566502)      True
# 2015-01-11                  ('asknacks', 2738399.7964948458)      True
# 2015-01-12             ('ballondor2014', 247885.29974936915)      True
# 2015-01-13                   ('stk2015', 241208.93218049174)      True
# 2015-01-14                     ('crc68', 60133.261174774671)      True
# 2015-01-15                      ('cdd15', 622271.8122847476)      True
# 2015-01-16      ('shawnsfirstheadlines', 1473591.7539621089)      True
# 2015-01-17          ('britonedirection', 4909293.2788397232)      True
# 2015-01-18                      ('soul', 19248.257935700709)      True
# 2015-01-19      ('shawnsfirstheadlines', 1161049.7480647499)      True
# 2015-01-20                     ('wef15', 66718.518633989646)      True
# 2015-01-21                     ('wef15', 311945.29294461152)      True
# 2015-01-22                     ('upr21', 181958.90743221517)      True
# 2015-01-23              ('felizviernes', 508228.45460435539)      True
# 2015-01-24                 ('saindavos', 254727.70580866362)      True
# 2015-01-25               ('intertorino', 272169.09324482834)      True
# 2015-01-26            ('isoladeifamosi', 66705.384022995218)      True
# ...                                                      ...       ...
# 2016-07-29             ('aldubsafezone', 1161458.5733781129)      True
# 2016-07-30             ('bernasconistas', 2069388.077628602)      True
# 2016-07-31           ('welcometomylife', 213365.67142348411)      True
# 2016-08-01          ('swissnationalday', 184122.10401832737)      True
# 2016-08-02               ('vitramuseum', 28572.656133867382)      True
# 2016-08-03                   ('domicim', 22160458.362273492)      True
# 2016-08-04                ('summer2016', 115624.47213200906)      True
# 2016-08-05              ('letmeloveyou', 94741.249079896705)      True
# 2016-08-06           ('rioolympics2016', 605078.44117138023)      True
# 2016-08-07   ('wewantdolantwinsinitaly', 1051266.9529405159)      True
# 2016-08-08             ('aldubsaafrica', 238526.82003135179)      True
# 2016-08-09   ('agustinbernasconitrendy', 346054.59500910656)      True
# 2016-08-10        ('aldubangpahintulot', 104262.23959056627)      True
# 2016-08-11                    ('sfcfcs', 547581.06951569649)      True
# 2016-08-12              ('aldub1ticket', 271581.13370556955)      True
# 2016-08-13          ('streetparade2016', 644578.53563926113)      True
# 2016-08-14   ('agustinbernasconitrendy', 25487.108956814893)      True
# 2016-08-15            ('buonferragosto', 58709.105312590211)      True
# 2016-08-16                  ('bscybbmg', 4371554.1489951136)      True
# 2016-09-06                    ('suipor', 24202433.130350348)      True
# 2016-09-07                ('appleevent', 167683.70655832038)      True
# 2016-09-08                ('cantongirl', 1024320.2158962623)      True
# 2016-09-09                    ('scbscl', 1437612.0621273089)      True
# 2016-09-10                  ('zucchero', 224900.22349758566)      True
# 2016-09-11                   ('soyluna', 995093.04827190738)      True
# 2016-09-12                   ('autavia', 439084.74470061908)      True
# 2016-09-13                     ('hrc33', 783069.88683716813)      True
# 2016-09-14              ('bfybangonsam', 571726.10001369833)      True
# 2016-09-15                      ('xf10', 1071850.0602331895)      True
# 2016-09-16          ('bfyconcertfinale', 1984120.8726314523)      True
#
#             place_value placeLatitude placeLongitude  \
# date
# 2014-12-28        192.0       46.3293         9.4055
# 2014-12-29         22.0       46.2504        8.27646
# 2014-12-30         10.0       46.2219        6.18194
# 2014-12-31         34.0       47.3774        8.53676
# 2015-01-01         70.0       47.7218        7.28274
# 2015-01-06               udineseroma  5.322071e+05
# 2015-01-07              charliehebdo  2.776892e+07
# 2015-01-08             jesuischarlie  3.089633e+05
# 2015-01-09               prisedotage  2.198994e+06
# 2015-01-10                   fcmfcsm  7.992691e+05
# 2015-01-11                  asknacks  2.738400e+06
# 2015-01-12             ballondor2014  2.478853e+05
# 2015-01-13                   stk2015  2.412089e+05
# 2015-01-14                     crc68  6.013326e+04
# 2015-01-15                     cdd15  6.222718e+05
# 2015-01-16      shawnsfirstheadlines  1.473592e+06
# 2015-01-17          britonedirection  4.909293e+06
# 2015-01-18                      soul  1.924826e+04
# 2015-01-19      shawnsfirstheadlines  1.161050e+06
# 2015-01-20                     wef15  6.671852e+04
# 2015-01-21                     wef15  3.119453e+05
# 2015-01-22                     upr21  1.819589e+05
# 2015-01-23              felizviernes  5.082285e+05
# 2015-01-24                 saindavos  2.547277e+05
# 2015-01-25               intertorino  2.721691e+05
# 2015-01-26            isoladeifamosi  6.670538e+04
# ...                              ...           ...
# 2016-07-29             aldubsafezone  1.161459e+06
# 2016-07-30            bernasconistas  2.069388e+06
# 2016-07-31           welcometomylife  2.133657e+05
# 2016-08-01          swissnationalday  1.841221e+05
# 2016-08-02               vitramuseum  2.857266e+04
# 2016-08-03                   domicim  2.216046e+07
# 2016-08-04                summer2016  1.156245e+05
# 2016-08-05              letmeloveyou  9.474125e+04
# 2016-08-06           rioolympics2016  6.050784e+05
# 2016-08-07   wewantdolantwinsinitaly  1.051267e+06
# 2016-08-08             aldubsaafrica  2.385268e+05
# 2016-08-09   agustinbernasconitrendy  3.460546e+05
# 2016-08-10        aldubangpahintulot  1.042622e+05
# 2016-08-11                    sfcfcs  5.475811e+05
# 2016-08-12              aldub1ticket  2.715811e+05
# 2016-08-13          streetparade2016  6.445785e+05
# 2016-08-14   agustinbernasconitrendy  2.548711e+04
# 2016-08-15            buonferragosto  5.870911e+04
# 2016-08-16                  bscybbmg  4.371554e+06
# 2016-09-06                    suipor  2.420243e+07
# 2016-09-07                appleevent  1.676837e+05
# 2016-09-08                cantongirl  1.024320e+06
# 2016-09-09                    scbscl  1.437612e+06
# 2016-09-10                  zucchero  2.249002e+05
# 2016-09-11                   soyluna  9.950930e+05
# 2016-09-12                   autavia  4.390847e+05
# 2016-09-13                     hrc33  7.830699e+05
# 2016-09-14              bfybangonsam  5.717261e+05
# 2016-09-15                      xf10  1.071850e+06
# 2016-09-16          bfyconcertfinale  1.984121e+06
#
# [527 rows x 7 columns]

# %% [markdown]
# # Topic Trend in different place

# %% [markdown]
# #### First create a dictionary of placeId to their all their hashtags

# %%
base1 = df1[['placeId', 'hashtags']].groupby('placeId').aggregate(lambda x: [i for l in x for i in l ])

# %%
base2 = df2[['placeId', 'hashtags']].groupby('placeId').aggregate(lambda x: [i for l in x for i in l ])

# %%
base3 = df3[['placeId', 'hashtags']].groupby('placeId').aggregate(lambda x: [i for l in x for i in l ])

# %%
twtter_count1 = df1.groupby('placeId').count()[['id']]
twtter_count2 = df2.groupby('placeId').count()[['id']]
twtter_count3 = df3.groupby('placeId').count()[['id']]

# %%
twtter_count1.columns = ['base_twitter_count']
twtter_count2.columns = ['base_twitter_count']
twtter_count3.columns = ['base_twitter_count']

# %%
twitter_count = pd.concat([twtter_count1, twtter_count2, twtter_count3], axis=1).fillna(0).apply(lambda x: np.sum(x), axis=1)

# %%
twitter_count = pd.DataFrame(twitter_count, columns=['base_twitter_count'])

# %% [markdown]
# #### Merge three part of data

# %%
c = pd.concat([base1, base2, base3], axis=1)

# %% [markdown]
# drop na

# %%
c.head()
# Out:
#                                                            hashtags  \
# 000831c517105356                                                NaN
# 000a93ad12003aaa  [Zurich, drs3, wikipedia, gdi, fb, Basel, FCB,...
# 000b5d1aada9dcaa  [jäten, creativemornings, SCB, HCFG, telezüri,...
# 0010c7694b04e371                                                 []
# 0013241b7342de79                                                 []
#
#                                                            hashtags  \
# 000831c517105356                                                NaN
# 000a93ad12003aaa  [Kreis11, Zürich, myclimate, Abflug, Amsterdam...
# 000b5d1aada9dcaa                                                NaN
# 0010c7694b04e371                                                NaN
# 0013241b7342de79                                                 []
#
#                                                            hashtags
# 000831c517105356                                                 []
# 000a93ad12003aaa  [GenevaMotorShow, PoloStMoritz2014, polo, resi...
# 000b5d1aada9dcaa                                                NaN
# 0010c7694b04e371                                                NaN
# 0013241b7342de79                                                NaN

# %%
c = c.applymap(lambda x: x if isinstance(x, list) else [])

# %%
base_dict_by_place = pd.DataFrame(c.apply(lambda x: [i for l in x for i in l], axis=1), columns=['hashtags'])

# %%
base_dict_by_place.head()
# Out:
#                                                            hashtags
# 000831c517105356                                                 []
# 000a93ad12003aaa  [Zurich, drs3, wikipedia, gdi, fb, Basel, FCB,...
# 000b5d1aada9dcaa  [jäten, creativemornings, SCB, HCFG, telezüri,...
# 0010c7694b04e371                                                 []
# 0013241b7342de79                                                 []

# %%
base_dict_by_place['dict'] = base_dict_by_place['hashtags'].apply(lambda x: count_hash_tags(pd.Series([x])))

# %%
base_dict_by_place['count'] = base_dict_by_place['hashtags'].apply(lambda x: len(x))

# %%
base_dict_by_place = pd.concat([twitter_count, base_dict_by_place], axis=1)

# %%
base_dict_by_place.head()
# Out:
#                   base_twitter_count  \
# 000831c517105356                 1.0
# 000a93ad12003aaa              2580.0
# 000b5d1aada9dcaa                46.0
# 0010c7694b04e371                 2.0
# 0013241b7342de79                 7.0
#
#                                                            hashtags  \
# 000831c517105356                                                 []
# 000a93ad12003aaa  [Zurich, drs3, wikipedia, gdi, fb, Basel, FCB,...
# 000b5d1aada9dcaa  [jäten, creativemornings, SCB, HCFG, telezüri,...
# 0010c7694b04e371                                                 []
# 0013241b7342de79                                                 []
#
#                                                                dict  count
# 000831c517105356                                                 {}      0
# 000a93ad12003aaa  {'g07f': 1, 'windowsphone81': 1, 'g07f7': 1, '...    779
# 000b5d1aada9dcaa  {'itunes': 1, 'flgi': 1, 'talktäglich': 1, 'ta...     32
# 0010c7694b04e371                                                 {}      0
# 0013241b7342de79                                                 {}      0

# %% [markdown]
# ### Topic Daily

# %%
total_base_dict_by_place = base_dict_by_place.copy()

# %%
df = df4[df4.day == days[0]]
place = total_base_dict_by_place.index[20]
total_base_dict_by_place.loc[place]
# Out:
# base_twitter_count                                                  265
# hashtags              [oldschool, landleben, merci, salts, old, open...
# dict                  {'landleben': 1, 'fbimschnee': 1, 'eychusrtang...
# count                                                               129
# Name: 00466891f6f1cb75, dtype: object

# %%
overal_topic(date_df=df[df.placeId == place], total_base_dict=total_base_dict_by_place.loc[place]['dict'], 
             total_N=total_base_dict_by_place.loc[place]['base_twitter_count'])
# Out:
# ([], 265.0)

# %%
total_base_dict_by_place.loc[place]['hashtags']
# Out:
# ['oldschool',
#  'landleben',
#  'merci',
#  'salts',
#  'old',
#  'openairlax',
#  '2488ch',
#  'lol',
#  'Manshaalah',
#  'smh',
#  'LondonOlympics',
#  'LondonOlympics',
#  'LondonOlympics',
#  'LondonOlympics',
#  'LondonOlympics',
#  'LondonOlympics',
#  'LondonOlympics',
#  'London2012',
#  'londonolympics',
#  'Olympics2012',
#  'londonolympics',
#  'Olympics2012',
#  'londonolympics',
#  'Olympics2012',
#  'Crazy',
#  'londonolympics',
#  'Olympics2012',
#  'lol',
#  'justsayin',
#  'londonolympics',
#  'Olympics2012',
#  'londonolympics',
#  'Olympics2012',
#  'Yolo',
#  'lol',
#  'TeamRamadan',
#  'fast',
#  'Ramadan',
#  'TeamRamadan',
#  'alhamdoullah',
#  'TeamRamadan',
#  'Yeahhh',
#  'Ohyeahh',
#  'LoOl',
#  'hamdoullah',
#  'TeamRamadan',
#  'lol',
#  'alhamdoullah',
#  'ThoughtsDuringSchool',
#  'Ugh',
#  'hateSnitchNiggas',
#  'Smh',
#  'OneThingYouWillNeverControl',
#  'Strange',
#  'LoOl',
#  'Yolo',
#  'TeamRamadan',
#  'iftour',
#  'Fajr',
#  'Yawn',
#  'Knutsford',
#  '22',
#  'JummaMubarak',
#  'it',
#  'Smh',
#  'Numericalskills',
#  'it',
#  'Yeaaah',
#  'Yeaaah',
#  'Hmm',
#  'Alhamdoullah',
#  'Crap',
#  'smh',
#  'WTH',
#  'EidMubarak',
#  'Why',
#  'NothingIsBetter',
#  'NothingIsBetter',
#  'YesIDidit',
#  'MissRamadan',
#  'Hellyeh',
#  'F',
#  'SchoolisOver',
#  'hmm',
#  'WTF',
#  'Yeahhhh',
#  'PlayMe',
#  'ckin',
#  'Ugh',
#  'fuccc',
#  'yeahhh',
#  'WTF',
#  'WTF',
#  'Leggo',
#  'GoObama',
#  '2012',
#  'GoObama',
#  'PresidentialDebate2012',
#  'Obama2012',
#  'Obama2012',
#  'ShitIsCrazy',
#  'Endomondo',
#  'tbt',
#  'ferien',
#  'eychusrtangcake',
#  'happybiryhdayfrogcake',
#  'angmahiwagangpulangpuno',
#  'switzerland',
#  'snow',
#  'trains',
#  'travel',
#  'Tomorrowland',
#  'FBimSchnee',
#  'skiing',
#  'shred',
#  'RicoimSchnee',
#  'lax',
#  'nznz',
#  'klischee',
#  '2488ch',
#  '2488ch',
#  'Switzerland',
#  'Mountains',
#  'Alps',
#  'Fischeralp',
#  'lax',
#  'Switzerland',
#  'Laxairpor',
#  'top2000']

# %%
b1 = total_base_dict_by_place.sort_values(by='base_twitter_count')

# %%
b1[b1.base_twitter_count > 100000].shape
# Out:
# (18, 4)

# %%
a = df4.groupby('placeId').count()

# %%
b2 = a.sort_values('id').tail(20)

# %%
[i for i in b1.index if i not in b2.index]
# Out:
# ['d634e9b0a9802b08',
#  'c20e0f5ae8fb9df3',
#  '01f8d411ccaff471',
#  '07d6509bb11fd7b1',
#  '28f11dd7e743a2b5',
#  '068c70be7b3a4cc2',
#  'dfbf4ce81da97883',
#  'ddcca24ee29ddff2',
#  '24292aa21cb92cd8',
#  'd969dab4efecff93']

# %%
for day in days[:1]:
    df = df4[df4.day == day]
    print(df.placeId.unique().shape, df.shape)
#     for place in total_base_dict_by_place.index:
#         result, total_N = overal_topic(date_df=df[df.placeId == place], 
#                          total_base_dict=total_base_dict_by_place.loc[place]['dict'], 
#                          total_N=total_base_dict_by_place.loc[place]['base_twitter_count'], 
#                          n=15)
        
#         total_base_dict_by_place.loc[place]['base_twitter_count'] = total_N 
#         a = [day]
#         a.extend(result)
#         l[place].append(a)
# Out:
# (540,) (4497, 8)

# %%
# l = collections.defaultdict(list)
# for day in days[:1]:
#     df = df4[df4.day == day]
#     for place in total_base_dict_by_place.index:
#         result, total_N = overal_topic(date_df=df[df.placeId == place], 
#                          total_base_dict=total_base_dict_by_place.loc[place]['dict'], 
#                          total_N=total_base_dict_by_place.loc[place]['base_twitter_count'], 
#                          n=15)
        
#         total_base_dict_by_place.loc[place]['base_twitter_count'] = total_N 
#         a = [day]
#         a.extend(result)
#         l[place].append(a)

# %%
a = [day]
result, total_N = overal_topic(df, total_base_dict, total_N)
a.extend(result)
v.append(a)

# %%
v = []
for i, day in zip(range(10000), days):
    df = df4[df4.day == day]
    a = [day]
    result, total_N = overal_topic(df, total_base_dict, total_N)
    a.extend(result)
    v.append(a)

# %%
days[:10]
# Out:
# array(['2014-12-28', '2014-12-29', '2014-12-30', '2014-12-31',
#        '2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#        '2015-01-05', '2015-01-06'], dtype=object)

# %%
df = df4[df4.day == days[0]]

# %%
df.head()
# Out:
#                    id      userId            createdAt  \
# 0  549296980607111170   428982361  2014-12-28 20:13:00
# 1  549302600894783489   636433553  2014-12-28 20:35:20
# 2  549306478994391040   554330030  2014-12-28 20:50:44
# 3  549320145890705408  2452701214  2014-12-28 21:45:03
# 4  549320743449014272  2452701214  2014-12-28 21:47:25
#
#                                                 text           placeId  \
# 0  What a news!!! 2015 is gonna be an awesome yea...  cd661902b07eb657
# 1                                 @sara_astorino :-)  cd661902b07eb657
# 2                             http://t.co/1jdNwQfych  cd661902b07eb657
# 3  Gotthard - What can I do: http://t.co/RrRna3K4...  cd661902b07eb657
# 4  Gotthard - What can I do: http://t.co/RrRna3K4...  cd661902b07eb657
#
#   hashtags                time         day
# 0       [] 2014-12-28 20:13:00  2014-12-28
# 1       [] 2014-12-28 20:35:20  2014-12-28
# 2       [] 2014-12-28 20:50:44  2014-12-28
# 3       [] 2014-12-28 21:45:03  2014-12-28
# 4       [] 2014-12-28 21:47:25  2014-12-28

# %%
gp = df[['placeId', 'hashtags']].groupby('placeId')

# %%
gp.aggregate(lambda x: [i for l in x for i in l ])
# Out:
#                                                            hashtags
# placeId
# 007355fb62ccfa7b                                                 []
# 010be04407bddf1a                                                 []
# 016897347bc6767a                                        [progressi]
# 017f355b6d0d683f                                                 []
# 019c9205eb7c7e1e                                                 []
# 01c6103f356d2f10                                   [Rhein, Germany]
# 01f8d411ccaff471  [ilovetravelling, geneva, airport, winter, bac...
# 0214be99e3147d06                                                 []
# 022473624806536d                                                 []
# 02e5e691d74c13e3                                                 []
# 0409a571f8ee4e19                                                 []
# 04578354cff6f4b1  [letitsnow, togheter, snow, vacanzedinatale, B...
# 047490f8ac8c2db7                                                 []
# 0474a793a39cfb12                                      [chat, perdu]
# 04f8296ceaf4e8fc                                                 []
# 05401d924e527c65                                [Buonanotte, cuore]
# 058d4d8bd84c5a25  [christmas, tree, christbaum, weihnachtsbaum, ...
# 05e07075e6cca12c                                                 []
# 062105b42eaf6038                                                 []
# 066547ab19059afd                                                 []
# 068c70be7b3a4cc2                                                 []
# 06a6d8266dcf1eb4                                                 []
# 074d8a7228cd4936                                       [schneegida]
# 0779c58412243b5e                                                 []
# 07bdea83b25f2852                                                 []
# 07d6509bb11fd7b1                                                 []
# 07df0bf4ff723c91                                                 []
# 07ff561fc8712ab4                                                 []
# 083a09c89f6e0079                                              [off]
# 08571a38aa5b52a6                                                 []
# ...                                                             ...
# e650f72d483c435d  [chaletseven, cransmontana, luxury, hotelbouti...
# e72d26c04aa570f0               [Pharmaceutical, Job, Aubonne, Jobs]
# ea3e42db51429c1f                                           [falcko]
# ea742e3372151811                                                 []
# ea9207bcd6b899a2                                                 []
# eaf4945d05594925                                                 []
# ec55d8788780f3cb                                                 []
# ec72c229283bb562  [together, JESC2014, JESC2013, switzerland, ju...
# ed39c670c6df65cc                                                 []
# ed3fe5eb360c6b7b                                                 []
# ed5277c2f0d909c1                                                 []
# ed643913fb3cab42                                          [vscocam]
# edc4e6d39c3a9b1e                                            [notte]
# ee3f5e5627afb978                                                 []
# f14beff7ac446d9f                                                 []
# f16dcc5e1bf017d7                                        [LRT, LAFN]
# f1993d4a5654aea2                                                 []
# f2e7e4fdc8cb8f49  [valferret, italiana, bigmtndreams, mountains,...
# f2f2caa600767ef4                                                 []
# f5904c3667a6d6dc                                                 []
# f5c89162d202cd90                                                 []
# f6c2608bd867e173                                [feliz, apaixonada]
# f77764d1ee0368e9                                                 []
# f9fb52b88f5c4f4f  [Luivedesolobianconero, sololaJuve, contappeto...
# fa342e611b0662c7                                                 []
# fa5507e962e64d07               [lindenstrasse, tatort, einschlafen]
# fdeba41ff7f777ff                                                 []
# fe635767f4779f0e                                                 []
# ffa4ff06c4fc16fb                                                 []
# ffa5c982527e9a43                                                 []
#
# [540 rows x 1 columns]
